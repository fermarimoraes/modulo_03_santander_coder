# %%
import pandas as pd

# %%
df_escolas = pd.read_csv('../datasets/escolas_transformado.csv')
df_material_didatico = pd.read_csv('../datasets/material_didatico_transformado.csv')
df_sub_prefeituras = pd.read_csv('../datasets/sub_prefeituras_transformado.csv')

df_rotas = df_escolas.join(df_material_didatico, lsuffix='_escola', rsuffix='_material_didatico').join(df_sub_prefeituras)
df_rotas
# Out:
#      Unnamed: 0_escola  id_escola  \
# 0                    0        178
# 1                    1        634
# 2                    2        483
# 3                    3        476
# 4                    4        132
# ..                 ...        ...
# 147                147        474
# 148                148        301
# 149                149        215
# 150                150        606
# 151                151         69
#
#                                   escolas_postos             bairro  \
# 0    CENTRO INTEGRADO DE EDUCACAO PUBLICA HENFIL               CAJU
# 1                     EM ALICE DO AMARAL PEIXOTO            BENFICA
# 2                             EM CELESTINO SILVA             CENTRO
# 3              ESCOLA MUNICIPAL FLORIANO PEIXOTO      SAO CRISTOVAO
# 4                              EM PEREIRA PASSOS       RIO COMPRIDO
# ..                                           ...                ...
# 147                  EM ENGENHEIRO GASTAO RANGEL          GUARATIBA
# ...
